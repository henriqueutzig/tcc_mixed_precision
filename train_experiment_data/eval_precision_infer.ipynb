# %% [markdown]
# # L40S

# %%
import pandas as pd
import seaborn as sns

import matplotlib.pyplot as plt

# The path to the CSV file
file_path = 'grace/results_inference_batch/summary.csv'

# Read the CSV file into a pandas DataFrame
df_summary = pd.read_csv(file_path)

# Display the first few rows of the DataFrame to verify it was read correctly
# For each model and precision combination, find the row with the maximum throughput
# This identifies the most performant batch size based on throughput
most_performant_idx = df_summary.groupby(['model', 'precision'])['throughput'].idxmax()
most_performant_df = df_summary.loc[most_performant_idx]

# Display the resulting DataFrame
print("Most performant configuration for each model and precision (based on max throughput):")
most_performant_df
# Out:
# Most performant configuration for each model and precision (based on max throughput):
#           model precision  batch_size   throughput  mean_latency_ms  \
# 17   bert-large      bf16          96  1463.385395        65.544996
# 35   bert-large      fp16          96  1398.791987        68.540220
# 45   bert-large      fp32          32   873.965595        36.554513
# 60         gpt2      bf16          24  1748.080075        13.610735
# 78         gpt2      fp16          24  1747.004903        13.633189
# 93         gpt2      fp32          16  1484.947235        10.672193
# 119    resnet50      bf16          48  4389.009610        10.887547
# 137    resnet50      fp16          48  4671.777143        10.226016
# 150    resnet50      fp32          24  2761.125633         8.656287
#
#      total_time_sec  success
# 17         3.280066        1
# 35         3.431532        1
# 45         1.830736        1
# 60         0.686467        1
# 78         0.686890        1
# 93         0.538740        1
# 119        0.546820        1
# 137        0.513723        1
# 150        0.434605        1

# %%
# Set the aesthetic style of the plots
sns.set_style("whitegrid")

# Create a faceted plot to compare throughput across different batch sizes for each model and precision
g = sns.relplot(
    data=df_summary,
    x='batch_size',
    y='throughput',
    hue='precision',
    col='model',
    kind='line',
    marker='o',  # Add markers to indicate the exact batch sizes tested
    col_wrap=3,  # Wrap the columns after 3 plots
    height=4,
    aspect=1.2,
    facet_kws={'sharey': False, 'sharex': False}
)

# Set titles and labels
g.fig.suptitle('Throughput vs. Batch Size by Model and Precision (L40S)', y=1.03)
g.set_axis_labels("Batch Size", "Throughput (samples/sec)")
g.set_titles("Model: {col_name}")

# Adjust layout to make room for the suptitle
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# # 4090

# %%
import pandas as pd

# The path to the CSV file
file_path = '4090/results_inference_batch/summary.csv'

# Read the CSV file into a pandas DataFrame
df_summary = pd.read_csv(file_path)

# Display the first few rows of the DataFrame to verify it was read correctly
# For each model and precision combination, find the row with the maximum throughput
# This identifies the most performant batch size based on throughput
most_performant_idx = df_summary.groupby(['model', 'precision'])['throughput'].idxmax()
most_performant_df = df_summary.loc[most_performant_idx]

# Display the resulting DataFrame
print("Most performant configuration for each model and precision (based on max throughput):")
most_performant_df
# Out:
# Most performant configuration for each model and precision (based on max throughput):
#           model precision  batch_size   throughput  mean_latency_ms  \
# 14   bert-large      bf16          64  1427.489324        44.789219
# 32   bert-large      fp16          64  1427.298357        44.794822
# 45   bert-large      fp32          32   818.972863        39.029064
# 63         gpt2      bf16          32  1476.547860        21.574659
# 81         gpt2      fp16          32  1504.658422        21.168408
# 96         gpt2      fp32          24  1230.183356        19.409523
# 122    resnet50      bf16          64  4768.425398        13.380094
# 140    resnet50      fp16          64  4882.464482        13.065829
# 153    resnet50      fp32          32  2704.236104        11.792059
#
#      total_time_sec  success
# 14         2.241698        1
# 32         2.241998        1
# 45         1.953667        1
# 63         1.083609        1
# 81         1.063364        1
# 96         0.975464        1
# 122        0.671081        1
# 140        0.655407        1
# 153        0.591664        1

# %%
# Set the aesthetic style of the plots
sns.set_style("whitegrid")

# Create a faceted plot to compare throughput across different batch sizes for each model and precision
g = sns.relplot(
    data=df_summary,
    x='batch_size',
    y='throughput',
    hue='precision',
    col='model',
    kind='line',
    marker='o',  # Add markers to indicate the exact batch sizes tested
    col_wrap=3,  # Wrap the columns after 3 plots
    height=4,
    aspect=1.2,
    facet_kws={'sharey': False, 'sharex': False}
)

# Set titles and labels
g.fig.suptitle('Throughput vs. Batch Size by Model and Precision (RTX 4090)', y=1.03)
g.set_axis_labels("Batch Size", "Throughput (samples/sec)")
g.set_titles("Model: {col_name}")

# Adjust layout to make room for the suptitle
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# # 7900

# %%
import pandas as pd

# The path to the CSV file
file_path = '7900/results_inference_batch/summary.csv'

# Read the CSV file into a pandas DataFrame
df_summary = pd.read_csv(file_path)

# Display the first few rows of the DataFrame to verify it was read correctly
# For each model and precision combination, find the row with the maximum throughput
# This identifies the most performant batch size based on throughput
most_performant_idx = df_summary.groupby(['model', 'precision'])['throughput'].idxmax()
most_performant_df = df_summary.loc[most_performant_idx]

# Display the resulting DataFrame
print("Most performant configuration for each model and precision (based on max throughput):")
most_performant_df
# Out:
# Most performant configuration for each model and precision (based on max throughput):
#           model precision  batch_size   throughput  mean_latency_ms  \
# 0    bert-large      bf16        1024   622.638502      1644.588785
# 18   bert-large      fp16        1024   615.111909      1664.711790
# 48   bert-large      fp32           4    46.564551        85.870838
# 60         gpt2      bf16          24   977.600759        24.495845
# 78         gpt2      fp16          24   979.201225        24.466958
# 98         gpt2      fp32           2   139.043125        14.335899
# 114    resnet50      bf16          24  1536.494691        15.600734
# 135    resnet50      fp16          32  3066.132167        10.416822
# 146    resnet50      fp32          12  1542.328782         7.761350
#
#      total_time_sec  success
# 0         82.230700        1
# 18        83.236886        1
# 48         4.295113        1
# 60         1.227495        1
# 78         1.225489        1
# 98         0.719201        1
# 114        0.780998        1
# 135        0.521830        1
# 146        0.389022        1

# %%
df_summary.sort_values(by=['throughput', 'model', 'precision', 'batch_size'], inplace=True, ascending=False)
# df_summary.filter(items=['model', 'precision', 'batch_size', 'throughput'])
# df_summary.where(df_summary['model'] == 'bert-large')
df_summary[(df_summary['model'] == 'gpt2') & ((df_summary['precision'] == 'fp16'))].head()
# Out:
#         model precision  batch_size   throughput  mean_latency_ms  \
# 135  resnet50      fp16          32  3066.132167        10.416822
# 132  resnet50      fp16          24  3054.173425         7.838922
# 137  resnet50      fp16          48  2943.131991        16.289911
# 140  resnet50      fp16          64  2819.247667        22.681251
# 129  resnet50      fp16          16  2812.126332         5.670424
#
#      total_time_sec  success
# 135        0.521830        1
# 132        0.392905        1
# 137        0.815458        1
# 140        1.135055        1
# 129        0.284482        1

# %%
df_summary[(df_summary['model'] == 'resnet50') & (df_summary['precision'] == 'bf16')].head()
# Out:
#         model precision  batch_size   throughput  mean_latency_ms  \
# 114  resnet50      bf16          24  1536.494691        15.600734
# 117  resnet50      bf16          32  1530.637304        20.886512
# 119  resnet50      bf16          48  1515.828353        31.645856
# 122  resnet50      bf16          64  1484.433677        43.093638
# 125  resnet50      bf16          96  1480.449050        64.824524
#
#      total_time_sec  success
# 114        0.780998        1
# 117        1.045316        1
# 119        1.583293        1
# 122        2.155704        1
# 125        3.242260        1

# %%
df_summary[(df_summary['model'] == 'resnet50') & (df_summary['precision'] == 'fp32')].head()
# Out:
#         model precision  batch_size   throughput  mean_latency_ms  \
# 146  resnet50      fp32          12  1542.328782         7.761350
# 147  resnet50      fp32          16  1519.064434        10.513096
# 150  resnet50      fp32          24  1505.236995        15.924869
# 153  resnet50      fp32          32  1447.018393        22.094426
# 155  resnet50      fp32          48  1391.951229        34.464126
#
#      total_time_sec  success
# 146        0.389022        1
# 147        0.526640        1
# 150        0.797217        1
# 153        1.105722        1
# 155        1.724198        1

# %%
df_summary[(df_summary['model'] == 'bert-large') & (df_summary['precision'] == 'fp16')].head()
# Out:
#          model precision  batch_size  throughput  mean_latency_ms  \
# 18  bert-large      fp16        1024  615.111909      1664.711790
# 32  bert-large      fp16          64  614.591347       104.112349
# 31  bert-large      fp16         512  613.838743       834.070177
# 33  bert-large      fp16         768  613.212960      1252.393556
# 22  bert-large      fp16         192  612.684659       313.352981
#
#     total_time_sec  success
# 18       83.236886        1
# 32        5.206712        1
# 31       41.704764        1
# 33       62.620986        1
# 22       15.668746        1

# %%
df_summary[(df_summary['model'] == 'bert-large') & (df_summary['precision'] == 'bf16')].head()
# Out:
#          model precision  batch_size  throughput  mean_latency_ms  \
# 0   bert-large      bf16        1024  622.638502      1644.588785
# 10  bert-large      bf16         384  621.730689       617.607980
# 15  bert-large      bf16         768  620.085516      1238.516054
# 14  bert-large      bf16          64  620.013995       103.192687
# 7   bert-large      bf16         256  619.696189       413.082886
#
#     total_time_sec  success
# 0        82.230700        1
# 10       30.881538        1
# 15       61.926942        1
# 14        5.161174        1
# 7        20.655283        1

# %%
df_summary[(df_summary['model'] == 'bert-large') & (df_summary['precision'] == 'fp32')].head()
# Out:
#          model precision  batch_size  throughput  mean_latency_ms  \
# 48  bert-large      fp32           4   46.564551        85.870838
# 44  bert-large      fp32           2   41.915351        47.694201
# 52  bert-large      fp32           8   36.957002       216.445603
# 39  bert-large      fp32          16   36.921366       433.331084
# 42  bert-large      fp32          24   36.839309       651.454926
#
#     total_time_sec  success
# 48        4.295113        1
# 44        2.385761        1
# 52       10.823389        1
# 39       21.667671        1
# 42       32.573901        1

# %%
# Set the aesthetic style of the plots
sns.set_style("whitegrid")

# Create a faceted plot to compare throughput across different batch sizes for each model and precision
g = sns.relplot(
    data=df_summary,
    x='batch_size',
    y='throughput',
    hue='precision',
    col='model',
    kind='line',
    marker='o',  # Add markers to indicate the exact batch sizes tested
    col_wrap=3,  # Wrap the columns after 3 plots
    height=4,
    aspect=1.2,
    facet_kws={'sharey': False, 'sharex': False}
)

# Set titles and labels
g.fig.suptitle('Throughput vs. Batch Size by Model and Precision (RX 7900XT)', y=1.03)
g.set_axis_labels("Batch Size", "Throughput (samples/sec)")
g.set_titles("Model: {col_name}")

# Adjust layout to make room for the suptitle
plt.tight_layout()

# Show the plot
plt.show()
