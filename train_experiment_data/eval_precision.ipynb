# %%
import os
import pandas as pd
from glob import glob

# Directory containing the CSV files
csv_dir = 'grace/results_precision_batch'

# Find all CSV files in the directory
csv_files = glob(os.path.join(csv_dir, '*.csv'))

# Helper function to get base name without suffix
def get_base_name(filename, suffix):
    if filename.endswith(suffix + '.csv'):
        return filename[:-len(suffix + '.csv')]
    elif filename.endswith('.csv'):
        return filename[:-4]
    return filename

amd_raw_metrics = pd.DataFrame()
df_metrics = pd.DataFrame()

# Group files by base name (with and without suffix)
for file_path in csv_files:
    filename = os.path.basename(file_path)
    if filename.endswith('raw_metrics.csv'):
        amd_raw_metrics = pd.concat([amd_raw_metrics, pd.read_csv(file_path)], ignore_index=True)
    else:
        df_metrics = pd.concat([df_metrics, pd.read_csv(file_path)], ignore_index=True)

# Find the index of the row with the maximum throughput for each model and precision
best_idx = df_metrics.groupby(['model', 'precision'])['avg_throughput_samples_per_sec'].idxmax()

# Select the best performing rows
best_performing_df = df_metrics.loc[best_idx]

# Sort by model and precision for better readability
best_performing_df = best_performing_df.sort_values(['model', 'precision'])

# Display the relevant columns
print("Best performing batch size for each model and precision:")
with pd.option_context('display.max_rows', None, 'display.max_columns', None, 'display.width', 1000):
    print(best_performing_df[['model', 'precision', 'batch_size', 'avg_throughput_samples_per_sec', 'peak_memory_mb', 'avg_utilization_percent', 'avg_power_watts']])
# Out:
# Best performing batch size for each model and precision:
#           model precision  batch_size  avg_throughput_samples_per_sec  peak_memory_mb  avg_utilization_percent  avg_power_watts
# 44   bert-large      bf16        96.0                      365.814863        18171.75                81.062500       273.583906
# 50   bert-large      fp16       256.0                      359.154913        38837.75                91.710526       296.055329
# 32   bert-large      fp32       192.0                      237.184660        43817.75                92.883721       315.314581
# 52         gpt2      bf16        32.0                      364.416601        10283.75                73.166667       241.070000
# 129        gpt2      fp16        32.0                      352.537009        10283.75                71.916667       242.023417
# 29         gpt2      fp32       128.0                      316.234632        35035.75                92.604651       288.165907
# ...

# %%
import seaborn as sns

import matplotlib.pyplot as plt

# Create a figure-level plot (relplot) to easily facet by model
g = sns.relplot(
    data=df_metrics,
    x='batch_size',
    y='avg_throughput_samples_per_sec',
    hue='precision',
    col='model',
    kind='line',
    marker='o',
    col_wrap=3, # Adjust the number of columns in the grid
    facet_kws={'sharey': False, 'sharex': False} # Allow axes to have different scales
)

# Add a title to the entire figure
g.fig.suptitle('Throughput vs. Batch Size for Each Model (L40S)', y=1.03)

# Improve layout
plt.tight_layout()
plt.show()

# %%
best_performing_df['throughput_per_watt'] = (
    best_performing_df['avg_throughput_samples_per_sec'] / best_performing_df['avg_power_watts']
)
best_performing_df['throughput_per_gb'] = (
    best_performing_df['avg_throughput_samples_per_sec'] / (best_performing_df['peak_memory_mb'] / 1024)
)

# Optional: sort by combined efficiency metric
best_performing_df['efficiency_score'] = (
    0.33 * best_performing_df['avg_throughput_samples_per_sec'].rank(ascending=False) +
    0.33 * best_performing_df['throughput_per_watt'].rank(ascending=False) +
    0.33 * best_performing_df['throughput_per_gb'].rank(ascending=False)
)

best_performing_df = best_performing_df.sort_values(['model', 'precision', 'efficiency_score'], ascending=[True, True, False])

print("Best performing batch size and efficiency metrics:")
with pd.option_context('display.max_columns', None):
    print(best_performing_df[['model', 'precision', 'batch_size',
                              'avg_throughput_samples_per_sec',
                              'throughput_per_watt',
                              'throughput_per_gb',
                              'avg_utilization_percent',
                              'peak_memory_mb',
                              'avg_power_watts']])
# Out:
# Best performing batch size and efficiency metrics:
#           model precision  batch_size  avg_throughput_samples_per_sec  \
# 44   bert-large      bf16        96.0                      365.814863
# 50   bert-large      fp16       256.0                      359.154913
# 32   bert-large      fp32       192.0                      237.184660
# 52         gpt2      bf16        32.0                      364.416601
# 129        gpt2      fp16        32.0                      352.537009
# 29         gpt2      fp32       128.0                      316.234632
# 33     resnet50      bf16        64.0                     1135.931242
# 42     resnet50      fp16        96.0                     1166.732691
# 13     resnet50      fp32        32.0                      657.235464
#
#      throughput_per_watt  throughput_per_gb  avg_utilization_percent  \
# 44              1.337121          20.614108                81.062500
# 50              1.213134           9.469514                91.710526
# ...

# %%
df_metrics[['model', 'precision', 'batch_size', 'avg_throughput_samples_per_sec', 'peak_memory_mb', 'avg_utilization_percent', 'avg_power_watts']].where(df_metrics['precision'] == 'bf16').where(df_metrics['model'] == 'bert-large').dropna().sort_values('avg_throughput_samples_per_sec', ascending=False).head(10)
# Out:
#           model precision  batch_size  avg_throughput_samples_per_sec  \
# 44   bert-large      bf16        96.0                      365.814863
# 21   bert-large      bf16       256.0                      363.523551
# 131  bert-large      bf16       128.0                      361.867442
# 88   bert-large      bf16        64.0                      360.922083
# 43   bert-large      bf16       192.0                      355.862700
# 75   bert-large      bf16        48.0                      334.058411
# 73   bert-large      bf16        32.0                      286.540714
# 8    bert-large      bf16        24.0                      243.725163
# 62   bert-large      bf16        16.0                      171.872857
# 111  bert-large      bf16        12.0                      120.399762
#
#      peak_memory_mb  avg_utilization_percent  avg_power_watts
# 44         18171.75                81.062500       273.583906
# 21         38837.75                91.815789       300.225211
# ...

# %%
df_metrics[['model', 'precision', 'batch_size', 'avg_throughput_samples_per_sec', 'peak_memory_mb', 'avg_utilization_percent', 'avg_power_watts']].where(df_metrics['precision'] == 'bf16').where(df_metrics['model'] == 'resnet50').dropna().sort_values('avg_throughput_samples_per_sec', ascending=False)
# Out:
#         model precision  batch_size  avg_throughput_samples_per_sec  \
# 33   resnet50      bf16        64.0                     1135.931242
# 121  resnet50      bf16        96.0                     1115.538462
# 94   resnet50      bf16       128.0                     1103.807555
# 22   resnet50      bf16        48.0                     1060.216906
# 15   resnet50      bf16       192.0                     1059.839193
# 67   resnet50      bf16       256.0                     1039.955752
# 47   resnet50      bf16       384.0                     1015.462969
# 98   resnet50      bf16       512.0                     1002.275890
# 63   resnet50      bf16       768.0                      992.931119
# 72   resnet50      bf16      1024.0                      978.487450
# 20   resnet50      bf16        32.0                      828.825126
# 93   resnet50      bf16        24.0                      662.206508
# 112  resnet50      bf16        16.0                      461.841476
# ...

# %%
import os
import pandas as pd
from glob import glob

# Directory containing the CSV files
csv_dir = '4090/results_precision_batch'

# Find all CSV files in the directory
csv_files = glob(os.path.join(csv_dir, '*.csv'))

# Helper function to get base name without suffix
def get_base_name(filename, suffix):
    if filename.endswith(suffix + '.csv'):
        return filename[:-len(suffix + '.csv')]
    elif filename.endswith('.csv'):
        return filename[:-4]
    return filename

amd_raw_metrics = pd.DataFrame()
df_metrics = pd.DataFrame()

# Group files by base name (with and without suffix)
for file_path in csv_files:
    filename = os.path.basename(file_path)
    if filename.endswith('raw_metrics.csv'):
        amd_raw_metrics = pd.concat([amd_raw_metrics, pd.read_csv(file_path)], ignore_index=True)
    else:
        df_metrics = pd.concat([df_metrics, pd.read_csv(file_path)], ignore_index=True)

# Find the index of the row with the maximum throughput for each model and precision
best_idx = df_metrics.groupby(['model', 'precision'])['avg_throughput_samples_per_sec'].idxmax()

# Select the best performing rows
best_performing_df = df_metrics.loc[best_idx]

# Sort by model and precision for better readability
best_performing_df = best_performing_df.sort_values(['model', 'precision'])

# Display the relevant columns
print("Best performing batch size for each model and precision:")
with pd.option_context('display.max_rows', None, 'display.max_columns', None, 'display.width', 1000):
    print(best_performing_df[['model', 'precision', 'batch_size', 'avg_throughput_samples_per_sec', 'peak_memory_mb', 'avg_utilization_percent', 'avg_power_watts']])
# Out:
# Best performing batch size for each model and precision:
#           model precision  batch_size  avg_throughput_samples_per_sec  peak_memory_mb  avg_utilization_percent  avg_power_watts
# 113  bert-large      bf16       128.0                      359.045454      22059.1875                77.288889       285.556133
# 61   bert-large      fp16       128.0                      355.336101      22059.1875                77.673913       283.353870
# 52   bert-large      fp32        96.0                      227.620252      24185.1875                80.607843       349.744569
# 71         gpt2      bf16        96.0                      413.641445      24477.1875                83.666667       271.383704
# 28         gpt2      fp16        96.0                      406.963279      24479.1875                84.074074       274.752593
# 58         gpt2      fp32        64.0                      329.167889      19703.1875                80.478261       280.383304
# ...

# %%
import seaborn as sns

import matplotlib.pyplot as plt

# Create a figure-level plot (relplot) to easily facet by model
g = sns.relplot(
    data=df_metrics,
    x='batch_size',
    y='avg_throughput_samples_per_sec',
    hue='precision',
    col='model',
    kind='line',
    marker='o',
    col_wrap=3, # Adjust the number of columns in the grid
    facet_kws={'sharey': False, 'sharex': False} # Allow axes to have different scales
)

# Add a title to the entire figure
g.fig.suptitle('Throughput vs. Batch Size for Each Model (RTX 4090)', y=1.03)

# Improve layout
plt.tight_layout()
plt.show()

# %%
df_metrics[['model', 'precision', 'batch_size', 'avg_throughput_samples_per_sec', 'peak_memory_mb', 'avg_utilization_percent', 'avg_power_watts']].where(df_metrics['precision'] == 'fp16').where(df_metrics['model'] == 'resnet50').dropna().sort_values('avg_throughput_samples_per_sec', ascending=False).head(10)
# Out:
#        model precision  batch_size  avg_throughput_samples_per_sec  \
# 45  resnet50      fp16       192.0                     1264.996591
# 5   resnet50      fp16       256.0                     1260.077823
# 98  resnet50      fp16       128.0                     1258.460994
# 22  resnet50      fp16       384.0                     1256.610856
# 92  resnet50      fp16       512.0                     1244.028212
# 33  resnet50      fp16        96.0                     1239.569288
# 68  resnet50      fp16        64.0                     1191.134145
# 64  resnet50      fp16        48.0                     1024.350276
# 66  resnet50      fp16        32.0                      758.606706
# 1   resnet50      fp16        24.0                      597.146604
#
#     peak_memory_mb  avg_utilization_percent  avg_power_watts
# 45      10177.1875                86.625000       290.472500
# 5       13511.1875                89.761905       301.718333
# ...

# %%
df_metrics[['model', 'precision', 'batch_size', 'avg_throughput_samples_per_sec', 'peak_memory_mb', 'avg_utilization_percent', 'avg_power_watts']].where(df_metrics['precision'] == 'bf16').where(df_metrics['model'] == 'resnet50').dropna().sort_values('avg_throughput_samples_per_sec', ascending=False).head(10)
# Out:
#         model precision  batch_size  avg_throughput_samples_per_sec  \
# 37   resnet50      bf16       384.0                     1221.968557
# 55   resnet50      bf16       256.0                     1216.189173
# 82   resnet50      bf16       512.0                     1215.915594
# 14   resnet50      bf16       192.0                     1213.628459
# 79   resnet50      bf16       128.0                     1204.717534
# 104  resnet50      bf16        96.0                     1187.566039
# 27   resnet50      bf16        64.0                     1158.978279
# 19   resnet50      bf16        48.0                     1042.865227
# 18   resnet50      bf16        32.0                      800.992718
# 78   resnet50      bf16        24.0                      624.556902
#
#      peak_memory_mb  avg_utilization_percent  avg_power_watts
# 37       19505.1875                94.121212       317.968182
# 55       13509.1875                90.909091       307.581818
# ...

# %%
import os
import pandas as pd
from glob import glob

# Directory containing the CSV files
csv_dir = '7900/results_precision_batch'

# Find all CSV files in the directory
csv_files = glob(os.path.join(csv_dir, '*.csv'))

# Helper function to get base name without suffix
def get_base_name(filename, suffix):
    if filename.endswith(suffix + '.csv'):
        return filename[:-len(suffix + '.csv')]
    elif filename.endswith('.csv'):
        return filename[:-4]
    return filename

amd_raw_metrics = pd.DataFrame()
df_metrics = pd.DataFrame()

# Group files by base name (with and without suffix)
for file_path in csv_files:
    filename = os.path.basename(file_path)
    if filename.endswith('raw_metrics.csv'):
        amd_raw_metrics = pd.concat([amd_raw_metrics, pd.read_csv(file_path)], ignore_index=True)
    else:
        df_metrics = pd.concat([df_metrics, pd.read_csv(file_path)], ignore_index=True)

# Find the index of the row with the maximum throughput for each model and precision
best_idx = df_metrics.groupby(['model', 'precision'])['avg_utilization_percent'].idxmax()

# Select the best performing rows
best_performing_df = df_metrics.loc[best_idx]

# Sort by model and precision for better readability
best_performing_df = best_performing_df.sort_values(['model', 'precision'])

# Display the relevant columns
print("Best performing batch size for each model and precision:")
with pd.option_context('display.max_rows', None, 'display.max_columns', None, 'display.width', 1000):
    print(best_performing_df[['model', 'precision', 'batch_size', 'avg_throughput_samples_per_sec', 'peak_memory_mb', 'avg_utilization_percent', 'avg_power_watts']])
# Out:
# Best performing batch size for each model and precision:
#          model precision  batch_size  avg_throughput_samples_per_sec  peak_memory_mb  avg_utilization_percent  avg_power_watts
# 97  bert-large      bf16        96.0                      164.104009    17539.566406                87.227273       240.545455
# 27  bert-large      fp16        96.0                      172.515614    17534.121094                86.218750       239.546875
# 0   bert-large      fp32        64.0                       25.945589    18037.191406                96.254902       264.980392
# 32        gpt2      bf16        64.0                      256.196885    16484.585938                75.843750       212.125000
# 94        gpt2      fp16        64.0                      253.137828    16476.093750                73.212121       205.545455
# 48        gpt2      fp32        64.0                       66.974688    19611.828125                92.735294       254.764706
# ...

# %%
import seaborn as sns

import matplotlib.pyplot as plt

# Create a figure-level plot (relplot) to easily facet by model
g = sns.relplot(
    data=df_metrics,
    x='batch_size',
    y='avg_throughput_samples_per_sec',
    hue='precision',
    col='model',
    kind='line',
    marker='o',
    col_wrap=3, # Adjust the number of columns in the grid
    facet_kws={'sharey': False, 'sharex': False} # Allow axes to have different scales
)

# Add a title to the entire figure
g.fig.suptitle('Throughput vs. Batch Size for Each Model (RX 7900XT)', y=1.03)

# Improve layout
plt.tight_layout()
plt.show()

# %%
df_metrics[['model', 'precision', 'batch_size', 'avg_throughput_samples_per_sec', 'peak_memory_mb', 'avg_utilization_percent', 'avg_power_watts']].where(df_metrics['precision'] == 'bf16').where(df_metrics['model'] == 'bert-large').dropna().sort_values('avg_throughput_samples_per_sec', ascending=False)
# Out:
#          model precision  batch_size  avg_throughput_samples_per_sec  \
# 97  bert-large      bf16        96.0                      164.104009
# 25  bert-large      bf16        64.0                      159.000648
# 16  bert-large      bf16        48.0                      153.249057
# 17  bert-large      bf16        32.0                      138.059406
# 69  bert-large      bf16        24.0                      129.200625
# 81  bert-large      bf16        16.0                      109.945385
# 44  bert-large      bf16        12.0                       95.400560
# 7   bert-large      bf16         8.0                       75.826360
# 37  bert-large      bf16         4.0                       46.059362
# 50  bert-large      bf16         2.0                       23.236521
# 76  bert-large      bf16         1.0                       11.704607
#
#     peak_memory_mb  avg_utilization_percent  avg_power_watts
# 97    17539.566406                87.227273       240.545455
# ...

# %%
df_metrics[['model', 'precision', 'batch_size', 'avg_throughput_samples_per_sec', 'peak_memory_mb', 'avg_utilization_percent', 'avg_power_watts']].where(df_metrics['precision'] == 'bf16').where(df_metrics['model'] == 'resnet50').dropna().sort_values('avg_throughput_samples_per_sec', ascending=False)
# Out:
#         model precision  batch_size  avg_throughput_samples_per_sec  \
# 31   resnet50      bf16       384.0                      103.684134
# 46   resnet50      bf16       256.0                       95.225375
# 1    resnet50      bf16       192.0                       89.582595
# 72   resnet50      bf16       128.0                       85.435477
# 99   resnet50      bf16        32.0                       85.088752
# 98   resnet50      bf16        48.0                       84.687029
# 41   resnet50      bf16        24.0                       84.505881
# 101  resnet50      bf16        64.0                       84.318157
# 19   resnet50      bf16        96.0                       83.399109
# 2    resnet50      bf16        16.0                       83.102192
# 68   resnet50      bf16        12.0                       80.430658
# 28   resnet50      bf16         8.0                       74.578751
# 11   resnet50      bf16         4.0                       58.429059
# ...

# %%
df_metrics[['model', 'precision', 'batch_size', 'avg_throughput_samples_per_sec', 'peak_memory_mb', 'avg_utilization_percent', 'avg_power_watts']].where(df_metrics['precision'] == 'bf16').where(df_metrics['model'] == 'gpt2').dropna().sort_values('avg_throughput_samples_per_sec', ascending=False).head(10)
# Out:
#    model precision  batch_size  avg_throughput_samples_per_sec  \
# 32  gpt2      bf16        64.0                      256.196885
# 34  gpt2      bf16        48.0                      245.762580
# 35  gpt2      bf16        32.0                      234.130750
# 90  gpt2      bf16        24.0                      228.750247
# 74  gpt2      bf16        16.0                      203.378344
# 13  gpt2      bf16        12.0                      183.993674
# 52  gpt2      bf16         8.0                      146.154760
# 22  gpt2      bf16         4.0                       91.324810
# 3   gpt2      bf16         2.0                       47.223738
# 80  gpt2      bf16         1.0                       23.670896
#
#     peak_memory_mb  avg_utilization_percent  avg_power_watts
# 32    16484.585938                75.843750       212.125000
# 34    12662.578125                68.142857       193.285714
# 35     8868.156250                62.050000       178.700000
# ...

# %%
# Load L40S data (from grace directory)
csv_dir_l40s = 'grace/results_precision_batch'
csv_files_l40s = glob(os.path.join(csv_dir_l40s, '*.csv'))
df_l40s = pd.DataFrame()
for file_path in csv_files_l40s:
    filename = os.path.basename(file_path)
    if not filename.endswith('raw_metrics.csv'):
        df_l40s = pd.concat([df_l40s, pd.read_csv(file_path)], ignore_index=True)

# Add GPU identifier to L40S data
df_l40s['gpu'] = 'NVIDIA L40S'

# Load RTX 4090 data
csv_dir_4090 = '4090/results_precision_batch'
csv_files_4090 = glob(os.path.join(csv_dir_4090, '*.csv'))
df_4090 = pd.DataFrame()
for file_path in csv_files_4090:
    filename = os.path.basename(file_path)
    if not filename.endswith('raw_metrics.csv'):
        df_4090 = pd.concat([df_4090, pd.read_csv(file_path)], ignore_index=True)

# Add GPU identifier to RTX 4090 data
df_4090['gpu'] = 'NVIDIA GeForce RTX 4090'

# Load RX 7900 data
csv_dir_7900 = '7900/results_precision_batch'
csv_files_7900 = glob(os.path.join(csv_dir_7900, '*.csv'))
df_7900 = pd.DataFrame()
for file_path in csv_files_7900:
    filename = os.path.basename(file_path)
    if not filename.endswith('raw_metrics.csv'):
        df_7900 = pd.concat([df_7900, pd.read_csv(file_path)], ignore_index=True)
df_7900['gpu'] = 'AMD Radeon RX 7900XT'

# Create separate heatmaps for each GPU
gpus_data = [
    (df_l40s, 'L40S'),
    (df_4090, 'RTX 4090'),
    (df_7900, 'RX 7900XT')
]

for df_gpu, gpu_name in gpus_data:
    # Skip if dataframe is empty or has no valid data
    if df_gpu.empty or 'avg_throughput_samples_per_sec' not in df_gpu.columns:
        print(f"Skipping {gpu_name} - no valid data")
        continue
    
    # Filter out rows with NaN values in required columns
    df_gpu_clean = df_gpu.dropna(subset=['model', 'precision', 'avg_throughput_samples_per_sec', 'batch_size'])
    
    if df_gpu_clean.empty:
        print(f"Skipping {gpu_name} - no clean data after filtering")
        continue
    
    # Get the row with maximum throughput for each model-precision combination
    max_throughput_idx = df_gpu_clean.groupby(['model', 'precision'])['avg_throughput_samples_per_sec'].idxmax()
    max_throughput_data = df_gpu_clean.loc[max_throughput_idx]
    
    # Create pivot tables for both throughput and batch size
    throughput_matrix = max_throughput_data.pivot(index='model', columns='precision', values='avg_throughput_samples_per_sec')
    batch_size_matrix = max_throughput_data.pivot(index='model', columns='precision', values='batch_size')
    
    # Create custom annotations combining throughput and batch size
    annotations = pd.DataFrame(index=throughput_matrix.index, columns=throughput_matrix.columns, dtype=str)
    for i in range(len(throughput_matrix.index)):
        for j in range(len(throughput_matrix.columns)):
            if pd.notna(throughput_matrix.iloc[i, j]):
                throughput = throughput_matrix.iloc[i, j]
                batch_size = batch_size_matrix.iloc[i, j]
                annotations.iloc[i, j] = f'{throughput:.1f}\n(bs={int(batch_size)})'
            else:
                annotations.iloc[i, j] = ''
    
    # Create heatmap
    sns.heatmap(throughput_matrix, 
                annot=annotations, 
                fmt='', 
                cmap='viridis', 
                cbar_kws={'label': 'Throughput (samples/sec)'},
                annot_kws={'size': 9})
   
    plt.title(f'Training: Optimal Batch Size for {gpu_name}')
    plt.xlabel('Precision')
    plt.ylabel('Model')
    plt.tight_layout()
    plt.show() 
    
    # # Create a separate figure for each GPU
    # plt.figure(figsize=(8, 6))
    # plt.savefig(f'{gpu_name}_train_throughput_heatmap.jpg', format='jpeg', dpi=300, bbox_inches='tight')
# Out:
# /var/folders/_b/xtqny3jn4xj460cq_85fbhn40000gn/T/ipykernel_17989/2583545630.py:8: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_l40s = pd.concat([df_l40s, pd.read_csv(file_path)], ignore_index=True)
# /var/folders/_b/xtqny3jn4xj460cq_85fbhn40000gn/T/ipykernel_17989/2583545630.py:20: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_4090 = pd.concat([df_4090, pd.read_csv(file_path)], ignore_index=True)
# ...

# %%
# Create separate line plots for L40S showing batch size vs throughput for each model
models = df_l40s['model'].unique()
gpu_name = df_l40s['gpu'].iloc[0]

# Define markers for each precision
precision_markers = {'fp32': '^', 'fp16': 's', 'bf16': 'o'}

for model in models:
    fig, ax = plt.subplots(figsize=(10, 7))
    model_data = df_l40s[df_l40s['model'] == model].dropna(subset=['batch_size', 'avg_throughput_samples_per_sec'])
    
    for precision in ['fp32', 'fp16', 'bf16']:
        precision_data = model_data[model_data['precision'] == precision].sort_values('batch_size')
        if not precision_data.empty:
            ax.plot(precision_data['batch_size'], 
                    precision_data['avg_throughput_samples_per_sec'],
                    marker=precision_markers[precision], 
                    label=precision,
                    linewidth=3,
                    markersize=10)
    
    ax.set_xlabel('Batch Size', fontsize=16, fontweight='bold')
    ax.set_ylabel(('Average Throughput (Samples/Sec)') if model == 'resnet50' else 'Average Throughput (Tokens/Sec)', fontsize=16, fontweight='bold')
    ax.legend(fontsize=14, loc='best')
    ax.grid(True, alpha=0.3)
    ax.tick_params(axis='both', which='major', labelsize=14)
    
    # # Add subtitle below the figure
    # fig.text(0.5, 0.02, f'{gpu_name} - {model}', 
    #          ha='center', fontsize=16, style='italic', fontweight='bold')
    
    plt.savefig(f'../batchsize/training_best_batchsize_{model}_{gpu_name.replace(" ", "_")}.png', dpi=300, bbox_inches='tight')
    
    plt.tight_layout(rect=[0, 0.04, 1, 1])
    plt.show()

# %%
# Create separate line plots for L40S showing batch size vs throughput for each model
models = df_4090['model'].unique()
gpu_name = df_4090['gpu'].iloc[0]

# Define markers for each precision
precision_markers = {'fp32': '^', 'fp16': 's', 'bf16': 'o'}

for model in models:
    fig, ax = plt.subplots(figsize=(10, 7))
    model_data = df_4090[df_4090['model'] == model].dropna(subset=['batch_size', 'avg_throughput_samples_per_sec'])
    
    for precision in ['fp32', 'fp16', 'bf16']:
        precision_data = model_data[model_data['precision'] == precision].sort_values('batch_size')
        if not precision_data.empty:
            ax.plot(precision_data['batch_size'], 
                    precision_data['avg_throughput_samples_per_sec'],
                    marker=precision_markers[precision], 
                    label=precision,
                    linewidth=3,
                    markersize=10)
    
    ax.set_xlabel('Batch Size', fontsize=16, fontweight='bold')
    ax.set_ylabel(('Average Throughput (Samples/Sec)') if model == 'resnet50' else 'Average Throughput (Tokens/Sec)', fontsize=16, fontweight='bold')
    ax.legend(fontsize=14, loc='best')
    ax.grid(True, alpha=0.3)
    ax.tick_params(axis='both', which='major', labelsize=14)
    
    # Add subtitle below the figure
    # fig.text(0.5, 0.02, f'{gpu_name}: {model} - Average Throughput vs Batch Size', 
    #          ha='center', fontsize=16, style='italic', fontweight='bold')
    
    plt.savefig(f'../batchsize/training_best_batchsize_{model}_{gpu_name.replace(" ", "_")}.png', dpi=300, bbox_inches='tight')
    plt.tight_layout(rect=[0, 0.04, 1, 1])
    plt.show()

# %%
# Create separate line plots for L40S showing batch size vs throughput for each model
models = df_7900['model'].unique()
gpu_name = df_7900['gpu'].iloc[0]

# Define markers for each precision
precision_markers = {'fp32': '^', 'fp16': 's', 'bf16': 'o'}

for model in models:
    fig, ax = plt.subplots(figsize=(10, 7))
    model_data = df_7900[df_7900['model'] == model].dropna(subset=['batch_size', 'avg_throughput_samples_per_sec'])
    
    for precision in ['fp32', 'fp16', 'bf16']:
        precision_data = model_data[model_data['precision'] == precision].sort_values('batch_size')
        if not precision_data.empty:
            ax.plot(precision_data['batch_size'], 
                    precision_data['avg_throughput_samples_per_sec'],
                    marker=precision_markers[precision], 
                    label=precision,
                    linewidth=3,
                    markersize=10)
    
    ax.set_xlabel('Batch Size', fontsize=16, fontweight='bold')
    ax.set_ylabel(('Average Throughput (Samples/Sec)') if model == 'resnet50' else 'Average Throughput (Tokens/Sec)', fontsize=16, fontweight='bold')
    ax.legend(fontsize=14, loc='best')
    ax.grid(True, alpha=0.3)
    ax.tick_params(axis='both', which='major', labelsize=14)
    
    # Add subtitle below the figure
    # fig.text(0.5, 0.02, f'{gpu_name}: {model} - Average Throughput vs Batch Size', 
    #          ha='center', fontsize=16, style='italic', fontweight='bold')
    
    plt.savefig(f'../batchsize/training_best_batchsize_{model}_{gpu_name.replace(" ", "_")}.png', dpi=300, bbox_inches='tight')
    plt.tight_layout(rect=[0, 0.04, 1, 1])
    plt.show()

# %%
# Combine all GPU data into one DataFrame
df_combined = pd.concat([df_l40s, df_4090, df_7900], ignore_index=True)

# Create separate plots for each GPU with better visual distinction
for gpu_name in df_combined['gpu'].unique():
    gpu_data = df_combined[df_combined['gpu'] == gpu_name]
    
    # Set the order of precision categories to ensure bf16 is drawn last (on top)
    precision_order = ['fp32', 'fp16', 'bf16']
    gpu_data['precision'] = pd.Categorical(gpu_data['precision'], categories=precision_order, ordered=True)
    gpu_data = gpu_data.sort_values('precision')
    
    # Create a faceted plot for this specific GPU with different markers and styles
    g = sns.relplot(
        data=gpu_data,
        x='batch_size',
        y='avg_throughput_samples_per_sec',
        hue='precision',
        hue_order=precision_order,  # Explicitly set the order
        style='precision',  # Add style mapping for better distinction
        col='model',
        kind='line',
        markers={'bf16': 'o', 'fp16': 's', 'fp32': '^'},  # Different markers
        dashes={'bf16': (2, 2), 'fp16': (1, 0), 'fp32': (5, 2, 1, 2)},  # Different line styles
        # palette='viridis',  # Use same color palette as heatmaps
        col_wrap=3,
        height=4,
        aspect=1.2,
        facet_kws={'sharey': False, 'sharex': False},
        linewidth=2,  # Make lines thicker
        markersize=8  # Make markers larger
    )
    
    # Set titles and labels
    g.fig.suptitle(f'Training: Throughput vs. Batch Size by Model and Precision ({gpu_name})', y=1.02)
    g.set_axis_labels('Batch Size', 'Throughput (Samples/Sec or Tokens/Sec)')
    g.set_titles("Model: {col_name}")
    
    # Improve legend
    g._legend.set_title('Precision')
    
    plt.tight_layout()
    plt.show()
# Out:
# /var/folders/_b/xtqny3jn4xj460cq_85fbhn40000gn/T/ipykernel_17989/3333407381.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gpu_data['precision'] = pd.Categorical(gpu_data['precision'], categories=precision_order, ordered=True)
# /var/folders/_b/xtqny3jn4xj460cq_85fbhn40000gn/T/ipykernel_17989/3333407381.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gpu_data['precision'] = pd.Categorical(gpu_data['precision'], categories=precision_order, ordered=True)
# ...
